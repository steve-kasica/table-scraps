# %%
import pandas as pd

# %%
# Load data
homes = pd.read_csv('notebooks/wuft/Power_of_Irma/Energy-Poverty 32641 homes.csv')

# Remove state from area name
#librarians.area_name = librarians.area_name.apply(lambda x: x.split(',')[0])

# Limit this to just the southwest
#librarians = librarians[librarians.prim_state.isin(['UT', 'CO', 'NM', 'AZ'])]

# Limit to just 
#librarians = librarians[['prim_state', 'area_name', 'tot_emp']]

homes.head()
# Out:
#    PREMISE_HOUSE_NUMBER PREMISE_STREET_NAME PREMISE_UNIT    StreetAddress  \
# 0                  1633          NE 10TH AV          NaN  1633 NE 10TH AV
# 1                  1630           NE 9TH AV          NaN   1630 NE 9TH AV
# 2                   914         NE 16TH TER          NaN  914 NE 16TH TER
# 3                   827         NE 15TH TER          NaN  827 NE 15TH TER
# 4                   927         NE 18TH TER          NaN  927 NE 18TH TER
#
#   PREMISE_CITY PREMISE_STATE  PREMISE_ZIP_CODE         PARCEL  Mean(YEAR)  \
# 0  GAINESVILLE            FL             32641  10675-001-000        2010
# 1  GAINESVILLE            FL             32641  10675-017-000        2010
# 2  GAINESVILLE            FL             32641  10676-008-000        2010
# 3  GAINESVILLE            FL             32641  10677-006-000        2010
# 4  GAINESVILLE            FL             32641  10733-005-000        2010
#
# ...

# %% [markdown]
# ## Cross tabulating from a within-table context

# %%
librarians.pivot(index='area_name', columns='prim_state', values='tot_emp')
# Out:
# prim_state                   AZ      CO     NM     UT
# area_name
# Albuquerque                 NaN     NaN  240.0    NaN
# Boulder                     NaN   180.0    NaN    NaN
# Colorado Springs            NaN   240.0    NaN    NaN
# Denver-Aurora-Broomfield    NaN  1050.0    NaN    NaN
# Farmington                  NaN     NaN   40.0    NaN
# Flagstaff                  60.0     NaN    NaN    NaN
# Fort Collins-Loveland       NaN   150.0    NaN    NaN
# Grand Junction              NaN    40.0    NaN    NaN
# Greeley                     NaN   120.0    NaN    NaN
# Las Cruces                  NaN     NaN   40.0    NaN
# Logan                       NaN     NaN    NaN   60.0
# Ogden-Clearfield            NaN     NaN    NaN   30.0
# Phoenix-Mesa-Glendale     950.0     NaN    NaN    NaN
# Prescott                   60.0     NaN    NaN    NaN
# Provo-Orem                  NaN     NaN    NaN  190.0
# Pueblo                      NaN    50.0    NaN    NaN
# ...
